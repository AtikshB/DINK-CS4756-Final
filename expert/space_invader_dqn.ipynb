# %% [markdown]
# # Space Invaders with dqn
#
# ## Step 1: Import the libraries

# %%
import time
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
import math

# %%
import sys
from agents.dqn_agent import DQNAgent
from models.dqn_cnn import DQNCnn
from preprocessing.stack_frame import preprocess_frame, stack_frame

# %% [markdown]
# ## Step 2: Create our environment
#
# Initialize the environment in the code cell below.

# %%
env = gym.make('SpaceInvaders-v0')
env.seed(0)
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]
# (2968811710, 3677149159)

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ", device)
# Out:
# Device:  cuda

# %% [markdown]
# ## Step 3: Viewing our Enviroment

# %%
print("The size of frame is: ", env.observation_space.shape)
print("No. of Actions: ", env.action_space.n)
env.reset()
plt.figure()
plt.imshow(env.reset())
plt.title('Original Frame')
plt.show()
# Out:
# The size of frame is:  (210, 160, 3)
# No. of Actions:  6

# %% [markdown]
# ### Execute the code cell below to play Pong with a random policy.

# %%
def random_play():
    score = 0
    env.reset()
    while True:
        action = env.action_space.sample()
        state, reward, done, _ = env.step(action)
        score += reward
        if done:
            env.close()
            print("Your Score at end of game is: ", score)
            break
random_play()
# Out:
# Your Score at end of game is:  90.0

# %% [markdown]
# ## Step 4:Preprocessing Frame

# %%
env.reset()
plt.figure()
plt.imshow(preprocess_frame(env.reset(), (8, -12, -12, 4), 84), cmap="gray")
plt.title('Pre Processed image')
plt.show()

# %% [markdown]
# ## Step 5: Stacking Frame

# %%
def stack_frames(frames, state, is_new=False):
    frame = preprocess_frame(state, (8, -12, -12, 4), 84)
    frames = stack_frame(frames, frame, is_new)

    return frames

# %% [markdown]
# ## Step 6: Creating our Agent

# %%
INPUT_SHAPE = (4, 84, 84)
ACTION_SIZE = env.action_space.n
SEED = 0
GAMMA = 0.99           # discount factor
BUFFER_SIZE = 100000   # replay buffer size
BATCH_SIZE = 64        # Update batch size
LR = 0.0001            # learning rate 
TAU = 1e-3             # for soft update of target parameters
UPDATE_EVERY = 1       # how often to update the network
UPDATE_TARGET = 10000  # After which thershold replay to be started 
EPS_START = 0.99       # starting value of epsilon
EPS_END = 0.01         # Ending value of epsilon
EPS_DECAY = 100         # Rate by which epsilon to be decayed

agent = DQNAgent(INPUT_SHAPE, ACTION_SIZE, SEED, device, BUFFER_SIZE, BATCH_SIZE, GAMMA, LR, TAU, UPDATE_EVERY, UPDATE_TARGET, DQNCnn)

# %% [markdown]
# ## Step 7: Watching untrained agent play

# %%
# watch an untrained agent
state = stack_frames(None, env.reset(), True) 
for j in range(200):
    action = agent.act(state)
    next_state, reward, done, _ = env.step(action)
    state = stack_frames(state, next_state, False)
    if done:
        break 
        
env.close()

# %% [markdown]
# ## Step 8: Loading Agent
# Uncomment line to load a pretrained agent

# %%
start_epoch = 0
scores = []
scores_window = deque(maxlen=20)

# %% [markdown]
# ## Step 9: Train the Agent with DQN

# %%
epsilon_by_epsiode = lambda frame_idx: EPS_END + (EPS_START - EPS_END) * math.exp(-1. * frame_idx /EPS_DECAY)

plt.plot([epsilon_by_epsiode(i) for i in range(1000)])

# %%
def train(n_episodes=1000):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
    """
    for i_episode in range(start_epoch + 1, n_episodes+1):
        state = stack_frames(None, env.reset(), True)
        score = 0
        eps = epsilon_by_epsiode(i_episode)
        while True:
            action = agent.act(state, eps)
            next_state, reward, done, info = env.step(action)
            score += reward
            next_state = stack_frames(state, next_state, False)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            if done:
                break
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
            fig = plt.figure()
            ax = fig.add_subplot(111)
            plt.plot(np.arange(len(scores)), scores)
            plt.ylabel('Score')
            plt.xlabel('Episode #')
            plt.show()
    
    return scores

# %%
scores = train(1000)
# Out:
# Episode 25	Average Score: 222.50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 scores = train(1000)
#
# Cell In[14], line 16, in train(n_episodes)
#      14 score += reward
#      15 next_state = stack_frames(state, next_state, False)
# ---> 16 agent.step(state, action, reward, next_state, done)
#      17 state = next_state
#      18 if done:
#
# File ~/SPRING2024/CS4756/CS4756_FinalProj_SpaceInvader/expert/agents/dqn_agent.py:76, in DQNAgent.step(self, state, action, reward, next_state, done)
#      73 if self.t_step == 0:
#      74     # If enough samples are available in memory, get random subset and learn
#      75     if len(self.memory) > self.replay_after:
# ---> 76         experiences = self.memory.sample()
#      77         self.learn(experiences)
#
# File ~/SPRING2024/CS4756/CS4756_FinalProj_SpaceInvader/expert/utils/replay_buffer.py:34, in ReplayBuffer.sample(self)
#      31 """Randomly sample a batch of experiences from memory."""
#      32 experiences = random.sample(self.memory, k=self.batch_size)
# ---> 34 states = torch.from_numpy(np.array([e.state for e in experiences if e is not None])).float().to(self.device)
#      35 actions = torch.from_numpy(np.array([e.action for e in experiences if e is not None])).long().to(self.device)
#      36 rewards = torch.from_numpy(np.array([e.reward for e in experiences if e is not None])).float().to(self.device)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 10: Watch a Smart Agent!

# %%
score = 0
state = stack_frames(None, env.reset(), True)
while True:
    env.render()
    action = agent.act(state)
    next_state, reward, done, _ = env.step(action)
    score += reward
    state = stack_frames(state, next_state, False)
    if done:
        print("You Final score is:", score)
        break 
env.close()
